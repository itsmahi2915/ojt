# %%
import pandas as pd 
df = pd.read_csv('hp.csv')
df.head(1)
# Out:
#    area localitis    price
# 0   550       old  1000000

# %%
#dummy
#one hot encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area       11 non-null     int64
#  1   localitis  11 non-null     object
#  2   price      11 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 396.0+ bytes

# %%
dummy = pd.get_dummies(df.localitis)
dummy
# Out:
#     center   city    old  station
# 0    False  False   True    False
# 1    False  False   True    False
# 2    False  False   True    False
# 3     True  False  False    False
# 4    False   True  False    False
# 5    False  False  False     True
# 6     True  False  False    False
# 7    False  False   True    False
# 8    False   True  False    False
# 9    False  False   True    False
# 10   False  False  False     True

# %%
#dummy.to_csv("dummy.csv")

# %%
merged = pd.concat([df,dummy],axis = 'columns')
merged
# Out:
#     area localitis    price  center   city    old  station
# 0    550       old  1000000   False  False   True    False
# 1    600       old  1200000   False  False   True    False
# 2    650       old  1500000   False  False   True    False
# 3    700    center  2000000    True  False  False    False
# 4    750      city  3200000   False   True  False    False
# 5    800   station  3800000   False  False  False     True
# 6    850    center  2000000    True  False  False    False
# 7    900       old  1500000   False  False   True    False
# 8    950      city  3200000   False   True  False    False
# 9   1000       old  1200000   False  False   True    False
# 10  1500   station  3200000   False  False  False     True

# %%
a = merged.drop(['localitis'],axis='columns')
a
# Out:
#     area    price  center   city    old  station
# 0    550  1000000   False  False   True    False
# 1    600  1200000   False  False   True    False
# 2    650  1500000   False  False   True    False
# 3    700  2000000    True  False  False    False
# 4    750  3200000   False   True  False    False
# 5    800  3800000   False  False  False     True
# 6    850  2000000    True  False  False    False
# 7    900  1500000   False  False   True    False
# 8    950  3200000   False   True  False    False
# 9   1000  1200000   False  False   True    False
# 10  1500  3200000   False  False  False     True

# %%
a.replace([True, False], [1,0] , inplace=True)
a
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18576\632917906.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   a.replace([True, False], [1,0] , inplace=True)
#     area    price  center  city  old  station
# 0    550  1000000       0     0    1        0
# 1    600  1200000       0     0    1        0
# 2    650  1500000       0     0    1        0
# 3    700  2000000       1     0    0        0
# 4    750  3200000       0     1    0        0
# 5    800  3800000       0     0    0        1
# 6    850  2000000       1     0    0        0
# 7    900  1500000       0     0    1        0
# 8    950  3200000       0     1    0        0
# 9   1000  1200000       0     0    1        0
# 10  1500  3200000       0     0    0        1

# %%
# one hot encoding

# %%
import pandas as pd 
df = pd.read_csv('hp.csv')
df.head(1)
# Out:
#    area localitis    price
# 0   550       old  1000000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a = df

# %%
a.localitis = le.fit_transform(a.localitis)
a
# Out:
#     area  localitis    price
# 0    550          2  1000000
# 1    600          2  1200000
# 2    650          2  1500000
# 3    700          0  2000000
# 4    750          1  3200000
# 5    800          3  3800000
# 6    850          0  2000000
# 7    900          2  1500000
# 8    950          1  3200000
# 9   1000          2  1200000
# 10  1500          3  3200000

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(a.drop('price', axis='columns'),a.price)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 748910.7519325376

# %%
model.coef_
# Out:
# array([  1725.93113141, -22382.29093465])

# %%
model.predict([[1500,3]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3270660.57624736])
