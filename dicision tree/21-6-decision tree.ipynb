# %%
import pandas as pd 
df = pd.read_csv('salary.csv')

# %%
df.head()
# Out:
#   company                  job     degree  salary
# 0  google      sales executive  bachelors       0
# 1  google      sales executive    masters       0
# 2  google     business manager  bachelors       1
# 3  google     business manager    masters       1
# 4  google  computer programmer  bachelors       0

# %%
x = df.drop('salary', axis='columns')
y = df['salary']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1 = LabelEncoder()
le2 = LabelEncoder()
Le3 = LabelEncoder()

# %%
df['company'] = lel.fit_transform(x['company'])
df['job'] = lel.fit_transform(x['job'])
df['degree'] = lel.fit_transform(x['degree'])

# %%
df
# Out:
#     company  job  degree  salary
# 0         2    2       0       0
# 1         2    2       1       0
# 2         2    0       0       1
# 3         2    0       1       1
# 4         2    1       0       0
# 5         2    1       1       1
# 6         0    2       1       0
# 7         0    1       0       0
# 8         0    0       0       0
# 9         0    0       1       1
# 10        1    2       0       1
# 11        1    2       1       1
# 12        1    0       0       1
# 13        1    0       1       1
# 14        1    1       0       1
# 15        1    1       1       1

# %%
from sklearn import tree
model= tree.DecisionTreeClassifier()

# %%
model.fit(df.drop('salary',axis='columns'),df.salary)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[2,2,1]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
#df.feature_names = list('company','job','degree')

# %%
#import numpy as np 
#class_names = np.array(['greater','lesser'])7

# %%
#import matplotlib.pyplot as plt 
#a = tree.plot_tree(model, feature_names=feature_names, class_names=class_names, filled=True)
