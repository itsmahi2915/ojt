# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head()
x = df['total_bill']
y=df['tip']

# %%
sns.scatterplot(x='total_bill' , y='tip' , data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=df, x='total_bill',y='size', hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.lineplot(data=df, x='total_bill',y='size', hue='sex', style='smoker', markers=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.lineplot(data=df, x='total_bill',y='size', hue='sex', style='smoker', markers=True, palette='Blues_d')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.lineplot(data=df, x='total_bill',y='size', hue='sex', style='smoker', markers=True, palette='Blues_d',dashes=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='size',y='total_bill',data=df)# here lines are confidence intervel
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size',y='total_bill',data=df,ci=True,color='yellow')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21996\1338463640.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', True)` for the same effect.
#
#   sns.barplot(x='size',y='total_bill',data=df,ci=True,color='yellow')
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size',y='total_bill',data=df,palette='Accent')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21996\2970757917.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='size',y='total_bill',data=df,palette='Accent')
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.histplot(x='size', data=df, bins=5,kde=True,color='orange')
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(x='size',data=df)

# %%
sns.kdeplot(x='size',data=df,hue='smoker',fill=True,linewidth=3)
# Out:
# <Axes: xlabel='size', ylabel='Density'>
